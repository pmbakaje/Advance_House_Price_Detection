# %%
# importing libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.pandas.set_option('display.max_columns',None)

# %%
# load dataset
dataset=pd.read_csv('train.csv')
                   
print(dataset.shape)
# Out:
# (1460, 81)

# %%
## checking null values
df=dataset.isnull().sum()
df
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Data Analysis
#
# 1. Missing value
# 2. All the Numeric variable
# 3. Distribution of numerical variable
# 4. Categorical variable
# 5. Cardinaility of categorical variable
# 6. Outliers
# 7. Relationship b/n indepedent and dependent feature(Salesprice)

# %%
# percentage of nan value 

feature_with_na=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>1]


for feature in feature_with_na:
    print(feature, np.round(dataset[feature].isnull().mean(),4), '% missing values.')
# Out:
# LotFrontage 0.1774 % missing values.
# Alley 0.9377 % missing values.
# MasVnrType 0.0055 % missing values.
# MasVnrArea 0.0055 % missing values.
# BsmtQual 0.0253 % missing values.
# BsmtCond 0.0253 % missing values.
# BsmtExposure 0.026 % missing values.
# BsmtFinType1 0.0253 % missing values.
# BsmtFinType2 0.026 % missing values.
# FireplaceQu 0.4726 % missing values.
# GarageType 0.0555 % missing values.
# GarageYrBlt 0.0555 % missing values.
# GarageFinish 0.0555 % missing values.
# GarageQual 0.0555 % missing values.
# GarageCond 0.0555 % missing values.
# PoolQC 0.9952 % missing values.
# Fence 0.8075 % missing values.
# MiscFeature 0.963 % missing values.

# %%
len(feature_with_na)
# Out:
# 18

# %% [markdown]
# # we have to find missing values and salesprice relation

# %%
for feature in feature_with_na:
    data=dataset.copy()
    # here we are making nan as 1 and other value as 1
    data[feature]=np.where(data[feature].isnull(),1,0)
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### here null value is more related to sales price hence wem have to take these values in feature engineering

# %%
print(f'ID of houses {len(dataset.Id)}')
# Out:
# ID of houses 1460

# %% [markdown]
# # Numerical variable

# %%
numerical_feature=[feature for feature in dataset.columns if dataset[feature].dtype!='O']

print(f'Number of numerical features are: {len(numerical_feature)}')

dataset[numerical_feature].head()
# Out:
# Number of numerical features are: 38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# ## Year Features

# %%
year_feature=[feature for feature in numerical_feature if 'Yr' in feature or 'Year' in feature]

year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
dataset.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('SalesPrice')
plt.title('Yearsold Vs Salesprice')
# Out:
# Text(0.5, 1.0, 'Yearsold Vs Salesprice')

# %% [markdown]
# #### Year increases the sales price median value also decreases

# %%
for feature in year_feature:
    if feature!='YrSold':
        data=dataset.copy()
        
        data[feature]=data['YrSold']-data[feature]
        
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %% [markdown]
# ## Descrete Variable

# %%
discrete_feature=[feature for feature in numerical_feature if len(dataset[feature].unique())<25 and feature not in year_feature]

print(f'Number of discrete features are: {len(discrete_feature)}')

discrete_feature
# Out:
# Number of discrete features are: 17
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
for feature in discrete_feature:
    data=dataset.copy()
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Sales Price')
    plt.show()

# %% [markdown]
# ### here few features are following trend line and few are not following we have to choose variable wisely in feature engineering

# %% [markdown]
# ## Contineous Feature

# %%
contineous_feature=[feature for feature in numerical_feature if feature not in discrete_feature+year_feature+['Id']]

print(f'contineous features are: {len(contineous_feature)}')

contineous_feature
# Out:
# contineous features are: 16
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for feature in contineous_feature:
    data=dataset.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# #### here less number of features are following guassian distribution curve

# %% [markdown]
# ### we are using logarithmic transformation for skewed variables

# %%
for feature in contineous_feature:
    data=dataset.copy()
    if 0 in data[feature].unique(): ## if feature contain 0 value then it will skip because log o is undefined
        pass
    else:
        data[feature]=np.log(data[feature])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('Sales Price')
        plt.title(feature)
        plt.show()

# %% [markdown]
# ####  Here features are linearly related

# %% [markdown]
# ## Outlier

# %%
for feature in contineous_feature:
    data=dataset.copy()
    if 0 in data[feature].unique(): 
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# ##### All contineous features are having outlier we need to handle these values

# %% [markdown]
# ## Categorical variable

# %%
categorical_feature=[feature for feature in dataset.columns if dataset[feature].dtype=='O']

categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
dataset[categorical_feature].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in categorical_feature:
    print(f'The feature is {feature} and number of categories are {len(dataset[feature].unique())}')
# Out:
# The feature is MSZoning and number of categories are 5
# The feature is Street and number of categories are 2
# The feature is Alley and number of categories are 3
# The feature is LotShape and number of categories are 4
# The feature is LandContour and number of categories are 4
# The feature is Utilities and number of categories are 2
# The feature is LotConfig and number of categories are 5
# The feature is LandSlope and number of categories are 3
# The feature is Neighborhood and number of categories are 25
# The feature is Condition1 and number of categories are 9
# The feature is Condition2 and number of categories are 8
# The feature is BldgType and number of categories are 5
# The feature is HouseStyle and number of categories are 8
# The feature is RoofStyle and number of categories are 6
# The feature is RoofMatl and number of categories are 8
# The feature is Exterior1st and number of categories are 15
# The feature is Exterior2nd and number of categories are 16
# ...

# %%
# relationship b/n categorical feature and sales price

for feature in categorical_feature:
    data=dataset.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Sales Price')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# 1. Missing value
# 2. Temporal variable
# 3. Categorical variable: remove rare variable
# 4. Standardize the value of the variable to the same range

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
X = dataset.drop('SalePrice', axis=1)
y = dataset['SalePrice']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1314, 80), (146, 80))

# %% [markdown]
# ## Missing value

# %%
# categorical missing value treatment

feature_nan=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>1 and dataset[feature].dtype=='O']

for feature in feature_nan:
    print(f'{feature}: {np.round(dataset[feature].isnull().mean(),4)} % missing values.')
# Out:
# Alley: 0.9377 % missing values.
# MasVnrType: 0.0055 % missing values.
# BsmtQual: 0.0253 % missing values.
# BsmtCond: 0.0253 % missing values.
# BsmtExposure: 0.026 % missing values.
# BsmtFinType1: 0.0253 % missing values.
# BsmtFinType2: 0.026 % missing values.
# FireplaceQu: 0.4726 % missing values.
# GarageType: 0.0555 % missing values.
# GarageFinish: 0.0555 % missing values.
# GarageQual: 0.0555 % missing values.
# GarageCond: 0.0555 % missing values.
# PoolQC: 0.9952 % missing values.
# Fence: 0.8075 % missing values.
# MiscFeature: 0.963 % missing values.

# %% [markdown]
# ##### 1) Alley, FireplaceQu, PoolQC, Fence, MiscFeature are having more missing values
# ##### 2) Remaining features are having less than 0.5% of values

# %%
## here we are replacing nan value with Missing value
def replace_cat_feature(dataset,feature_nan):
    data=dataset.copy()
    data[feature_nan]=data[feature_nan].fillna('Missing')
    return data

dataset=replace_cat_feature(dataset, feature_nan)

dataset[feature_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# numerical variable contain missing value
numerical_nan=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>1 and dataset[feature].dtype!='O']

for feature in numerical_nan:
    print(f'{feature}: {np.round(dataset[feature].isnull().mean(),4)} % missing values.')
# Out:
# LotFrontage: 0.1774 % missing values.
# MasVnrArea: 0.0055 % missing values.
# GarageYrBlt: 0.0555 % missing values.

# %%
## here we are replacing numerical nan value with median value with respect to variable
for feature in numerical_nan:
    median_value=dataset[feature].median()
    
    dataset[feature+'nan']=np.where(dataset[feature].isnull(),1,0)
    dataset[feature].fillna(median_value,inplace=True)
    
dataset[numerical_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
## here we are updating year column to only years based on year sold
for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    dataset[feature]=dataset['YrSold']-dataset[feature]

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataset[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
numerical_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
numerical_feature=[feature for feature in dataset.columns if dataset[feature].dtype!='O' and 0 not in data[feature]]

# %%
dataset.drop(['LotFrontagenan', 'MasVnrAreanan','GarageYrBltnan'],axis=1,inplace=True)

# %%
num_feature
# Out:
# []

# %%
for feature in num_feature:
    dataset[feature]=np.log(dataset[feature])

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     1.428968  2.201872   Pave  Missing      Reg
# 1   2          20       RL     1.477511  2.215885   Pave  Missing      Reg
# 2   3          60       RL     1.439718  2.233034   Pave  Missing      IR1
# 3   4          70       RL     1.409607  2.215315   Pave  Missing      IR1
# 4   5          60       RL     1.488584  2.258133   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Handeling rare cat feature

# %%
cat_feature=[feature for feature in dataset.columns if dataset[feature].dtype=='O']

cat_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in cat_feature:
    temp=dataset.groupby(feature)['SalePrice'].count()/len(dataset)
    temp_df=temp[temp>0.01].index
    dataset[feature]=np.where(dataset[feature].isin(temp_df),dataset[feature],'Rare_var')

# %%
dataset.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0     1          60       RL     1.428968  2.201872   Pave  Missing      Reg
# 1     2          20       RL     1.477511  2.215885   Pave  Missing      Reg
# 2     3          60       RL     1.439718  2.233034   Pave  Missing      IR1
# 3     4          70       RL     1.409607  2.215315   Pave  Missing      IR1
# 4     5          60       RL     1.488584  2.258133   Pave  Missing      IR1
# ..  ...         ...      ...          ...       ...    ...      ...      ...
# 95   96          60       RL     1.443172  2.217742   Pave  Missing      IR2
# 96   97          20       RL     1.471717  2.223152   Pave  Missing      IR1
# 97   98          20       RL     1.456394  2.229847   Pave  Missing      Reg
# 98   99          30       RL     1.491251  2.226887   Pave  Missing      Reg
# 99  100          20       RL     1.468751  2.212651   Pave  Missing      IR1
#
# ...

# %% [markdown]
# ## Feature Scaling

# %%
dataset.groupby(['MSZoning'])['SalePrice'].mean()
# Out:
# MSZoning
# FV          12.246616
# RH          11.749840
# RL          12.085885
# RM          11.692893
# Rare_var    11.118259
# Name: SalePrice, dtype: float64

# %%
for feature in cat_feature:
    labels_ordered=dataset.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    dataset[feature]=dataset[feature].map(labels_ordered)

# %%
dataset.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1          60         3     1.428968  2.201872       1      2         0
# 1   2          20         3     1.477511  2.215885       1      2         0
# 2   3          60         3     1.439718  2.233034       1      2         1
# 3   4          70         3     1.409607  2.215315       1      2         1
# 4   5          60         3     1.488584  2.258133       1      2         1
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            1          1          0          0            14           2
# 1            1          1          2          0            11           1
# 2            1          1          0          0            14           2
# 3            1          1          1          0            16           2
# 4            1          1          2          0            22           2
#
# ...

# %%
labels_ordered
# Out:
# {'Abnorml': 0, 'Rare_var': 1, 'Family': 2, 'Normal': 3, 'Partial': 4}

# %%
feature_scale=[feature for feature in dataset.columns if feature not in ['Id','SalePrice']]

# %%
dataset[feature_scale].head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0          60       RL     1.428968  2.201872   Pave  Missing      Reg
# 1          20       RL     1.477511  2.215885   Pave  Missing      Reg
# 2          60       RL     1.439718  2.233034   Pave  Missing      IR1
# 3          70       RL     1.409607  2.215315   Pave  Missing      IR1
# 4          60       RL     1.488584  2.258133   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl     Rare_var      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler # scale down data  b/n 0 to 1
scaler=MinMaxScaler()
scaler.fit(dataset[feature_scale])
# Out:
# MinMaxScaler()

# %%
scaler.transform(dataset[feature_scale])
# Out:
# array([[0.23529412, 0.75      , 0.49689213, ..., 0.5       , 0.66666667,
#         0.75      ],
#        [0.        , 0.75      , 0.57331546, ..., 0.25      , 0.66666667,
#         0.75      ],
#        [0.23529412, 0.75      , 0.51381745, ..., 0.5       , 0.66666667,
#         0.75      ],
#        ...,
#        [0.29411765, 0.75      , 0.50263957, ..., 1.        , 0.66666667,
#         0.75      ],
#        [0.        , 0.75      , 0.51381745, ..., 1.        , 0.66666667,
#         0.75      ],
#        [0.        , 0.75      , 0.54995643, ..., 0.5       , 0.66666667,
#         0.75      ]])

# %%
data=pd.concat([dataset[['Id','SalePrice']].reset_index(drop=True),
                 pd.DataFrame(scaler.transform(dataset[feature_scale]),columns=feature_scale)],axis=1)

# %%
data.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1  12.247694    0.235294      0.75     0.496892  0.431124     1.0    1.0
# 1   2  12.109011    0.000000      0.75     0.573315  0.457169     1.0    1.0
# 2   3  12.317167    0.235294      0.75     0.513817  0.489044     1.0    1.0
# 3   4  11.849398    0.294118      0.75     0.466412  0.456111     1.0    1.0
# 4   5  12.429216    0.235294      0.75     0.590747  0.535696     1.0    1.0
#
#    LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0  0.000000     0.333333        1.0       0.00        0.0      0.636364
# 1  0.000000     0.333333        1.0       0.50        0.0      0.500000
# 2  0.333333     0.333333        1.0       0.00        0.0      0.636364
# 3  0.333333     0.333333        1.0       0.25        0.0      0.727273
# 4  0.333333     0.333333        1.0       0.50        0.0      1.000000
#
# ...

# %%
data.to_csv('X_train.csv',index=False)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
dataset=pd.read_csv('X_train.csv')

# %%
dataset.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1  12.247694    0.235294      0.75     0.496892  0.431124     1.0    1.0
# 1   2  12.109011    0.000000      0.75     0.573315  0.457169     1.0    1.0
# 2   3  12.317167    0.235294      0.75     0.513817  0.489044     1.0    1.0
# 3   4  11.849398    0.294118      0.75     0.466412  0.456111     1.0    1.0
# 4   5  12.429216    0.235294      0.75     0.590747  0.535696     1.0    1.0
#
#    LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0  0.000000     0.333333        1.0       0.00        0.0      0.636364
# 1  0.000000     0.333333        1.0       0.50        0.0      0.500000
# 2  0.333333     0.333333        1.0       0.00        0.0      0.636364
# 3  0.333333     0.333333        1.0       0.25        0.0      0.727273
# 4  0.333333     0.333333        1.0       0.50        0.0      1.000000
#
# ...

# %%
y_train=dataset[['SalePrice']]
X_train=dataset.drop(['Id','SalePrice'],axis=1)
